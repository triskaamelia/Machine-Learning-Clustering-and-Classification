# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df = pd.read_csv('fix_air_bnb.csv')
df.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood  latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  0.801163  -0.061002
# 1                  Pankow  Prenzlauer Berg Nordwest  1.254363  -0.026598
# 2                  Pankow   Prenzlauer Berg Südwest  0.816044   0.197933
# 3  Tempelhof - Schöneberg           Schöneberg-Nord -0.355954  -0.983069
# 4                  Pankow            Helmholtzplatz  1.080693   0.155054
#
# ...

# %%
df['cluster'] = np.random.randint(3, size=22467)

# %%
df.cluster
# Out:
# 0        0
# 1        1
# 2        2
# 3        2
# 4        0
#         ..
# 22462    2
# 22463    1
# 22464    2
# 22465    1
# 22466    2
# Name: cluster, Length: 22467, dtype: int32

# %%
# split dataset menjadi 4 jenis dataset
# X_train : berisikan seluruh baris pada dataset yang bukan atribut kelas, digunakan sebagai data latih
# X_test : berisikan seluruh baris pada dataset yang bukan atribut kelas, digunakan sebagai data uji
# Y_train : berisikan seluruh baris pada dataset dengan atribut hanyalah atribut kelas, digunakan sebagai data latih kelas
# Y_test : berisikan seluruh baris pada dataset dengan atribut hanyalah atribut kelas, digunakan sebagai data uji kelas
X = df.iloc[:,[6,7]].values
Y = df.iloc[:,-1].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)
# split lagi untuk membuat 2 jenis dataset, dimana dataset ini dapat digunakan untuk keperluan validasi
#X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=1)

# %%
# memasukan pengklasifikasi ke data latih
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train,Y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# memprediksi nilai class milik semua data uji
Y_pred = classifier.predict(X_test)

# %%
for i in Y_pred:
    print(i)
# Out:
# 0
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 0
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 1
# 2
# 1
# 0
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 1
# 2
# 2
# 0
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 0
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 0
# 2
# 1
# 2
# 2
# 0
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 1
# 0
# 0
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 1
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 0
# 2
# 2
# 2
# 2
# 0
# 2
# 2
# 1
# ...

# %%
# melihat keoptimalan classification dengan menggunakan confusion matrix
from sklearn.metrics import confusion_matrix, f1_score,precision_score,recall_score
import sklearn.metrics as skm
cm = confusion_matrix(Y_test, Y_pred)
print('confusion matrix')
print(cm)
print('')
conf = skm.multilabel_confusion_matrix(Y_test, Y_pred)
print('multilable confusion matrix')
print(conf)
print('')
print('--- Informasi Rumus Perhitungan ---')
print('accuracy = ((tp+tn)/(tp+tn+fp+fn))*100')
print('precision = (tp/(fp+tp))*100')
print('recall = (tp/(fn+tp))*100')
print('f1_score = 2* ((recall*presisi)/(recall+presisi))')
print('')
print( skm.classification_report(Y_test,Y_pred))
print('micro avg')
print('precision: ', precision_score(Y_test, Y_pred, average="micro"))
print('recall: ', recall_score(Y_test, Y_pred, average="micro"))
print('f1-score: ', f1_score(Y_test, Y_pred, average="micro"))
# Out:
# confusion matrix
# [[ 169  185 1497]
#  [ 152  203 1545]
#  [ 172  171 1523]]
#
# multilable confusion matrix
# [[[3442  324]
#   [1682  169]]
#
#  [[3361  356]
#   [1697  203]]
#
#  [[ 709 3042]
#   [ 343 1523]]]
#
# --- Informasi Rumus Perhitungan ---
# accuracy = ((tp+tn)/(tp+tn+fp+fn))*100
# precision = (tp/(fp+tp))*100
# recall = (tp/(fn+tp))*100
# f1_score = 2* ((recall*presisi)/(recall+presisi))
#
#               precision    recall  f1-score   support
#
#            0       0.34      0.09      0.14      1851
#            1       0.36      0.11      0.17      1900
#            2       0.33      0.82      0.47      1866
#
#     accuracy                           0.34      5617
#    macro avg       0.35      0.34      0.26      5617
# weighted avg       0.35      0.34      0.26      5617
#
# micro avg
# precision:  0.3373687021541748
# recall:  0.3373687021541748
# f1-score:  0.3373687021541748

# %%
# memvisualisasikan hasil data latih
from matplotlib.colors import ListedColormap
X_set, Y_set = X_train, Y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.30, cmap = ListedColormap(('blue', 'orange','green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(Y_set)):
    plt.scatter(X_set[Y_set == j, 0], X_set[Y_set == j, 1],
                c = ListedColormap(('blue', 'orange','green'))(i), label = j)
plt.title('Naive Bayes (Training set)')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.legend()
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# memvisualisasikan hasil data uji
from matplotlib.colors import ListedColormap
X_set, Y_set = X_test, Y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.30, cmap = ListedColormap(('blue', 'orange','green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(Y_set)):
    plt.scatter(X_set[Y_set == j, 0], X_set[Y_set == j, 1],
                c = ListedColormap(('blue', 'orange','green'))(i), label = j)
plt.title('Naive Bayes (Test set)')
plt.xlabel('number_of_reviews')
plt.ylabel('reviews_per_month')
plt.legend()
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
print('1 : daerah 1')
print('0 : daerah 3')
print('2 : daerah 2')
# Out:
# 1 : daerah 1
# 0 : daerah 3
# 2 : daerah 2

# %%
df.sort_values(by=['latitude','cluster'])
# Out:
#              id                                          name    host_id  \
# 518      555352                 Caravan Landhaus Seeapartment    2677541
# 508      542316                                   by the lake    2677541
# 887      941115                           Zimmer Seepferdchen    2677541
# 3342    5082170                 Fe-Wo "Seelöwe" in berlin99de    2677541
# 20309  27197829                      Ferienhaus am Krossinsee   39574419
# ...         ...                                           ...        ...
# 3785    5822783            Four delicious rooms (Berlin-Buch)    3046997
# 7763   11542501                           Grün und komfortabl   60897763
# 17952  23761144  Haus im Grünen, komfortabel, möbliert, ruhig  178198232
# 21627  28891662                        Schönes eigenes Zimmer  217794326
# 4424    6847300             Extraklasse im grünen Berliner NO   35879715
#
#       host_name neighbourhood_group  \
# 518     Dimitri  Treptow - Köpenick
# ...

# %%
# membuat file csv
df['cluster'].replace(1,'daerah 1',inplace=True)
df['cluster'].replace(2,'daerah 2',inplace=True)
df['cluster'].replace(0,'daerah 3',inplace=True)

# %%
cek = df.loc[:,'cluster'].values
from collections import Counter
Counter(cek)
# Out:
# Counter({'daerah 3': 7417, 'daerah 1': 7435, 'daerah 2': 7615})

# %%
df.to_csv('HasilModifikasi2_air_bnb.csv',index=False)
